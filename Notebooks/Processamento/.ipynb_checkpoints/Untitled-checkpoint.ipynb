# %%
#Análise exploratória de Dados em Python
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#dados_inmet_bh_2020.to_csv (r'/home/marcelo/Documentos/PosGraduacaoDataScience/Disciplinas/Monografia/DadosMonografia/dados_inmet_filtrados_2020.csv', index = False, header=True)
path=('/home/marcelo/Documentos/PosGraduacaoDataScience/Disciplinas/Monografia/DadosMonografia/dados_inmet_filtrados_2020.csv')
df=pd.read_csv(path)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8781 entries, 0 to 8780
# Data columns (total 18 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Data                                                   8781 non-null   object
#  1   Hora UTC                                               8781 non-null   object
#  2   PRECIPITACAO TOTAL. HORARIO (mm)                       8781 non-null   float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  8781 non-null   float64
#  4   PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        8781 non-null   float64
#  5   PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       8781 non-null   float64
#  6   TEMPERATURA DO AR - BULBO SECO. HORARIA (Celsius)      8781 non-null   float64
#  7   TEMPERATURA DO PONTO DE ORVALHO (Celsius)              8781 non-null   float64
# ...

# %%
#https://operdata.com.br/blog/coeficientes-de-correlacao/#:~:text=O%20coeficiente%20de%20correla%C3%A7%C3%A3o%20de,situados%20entre%20%2D1%20e%201.&text=Isso%20%C3%A9%20o%20que%20%C3%A9%20chamado%20de%20correla%C3%A7%C3%A3o%20negativa%20ou%20inversa.
#Usando a correlacao linear entre as variáveis

plt.matshow(df.corr())
plt.show()

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %%
#Gerando a analise de correlação

rs = np.random.RandomState(0)
#df = pd.DataFrame(rs.rand(10, 10))
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# 'RdBu_r', 'BrBG_r', & PuOr_r are other good diverging colormaps
# Out:
# <style  type="text/css" >
#     #T_69ce6fa2_e18c_11eb_91d5_4dd0631c3165row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_69ce6fa2_e18c_11eb_91d5_4dd0631c3165row0_col1 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_69ce6fa2_e18c_11eb_91d5_4dd0631c3165row0_col2 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_69ce6fa2_e18c_11eb_91d5_4dd0631c3165row0_col3 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_69ce6fa2_e18c_11eb_91d5_4dd0631c3165row0_col4 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_69ce6fa2_e18c_11eb_91d5_4dd0631c3165row0_col5 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_69ce6fa2_e18c_11eb_91d5_4dd0631c3165row0_col6 {
#             background-color:  #bfd3f6;
#             color:  #000000;
# ...

# %%
corr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, PRECIPITACAO TOTAL. HORARIO (mm) to VENTO. VELOCIDADE HORARIA (m/s);
# Data columns (total 16 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   PRECIPITACAO TOTAL. HORARIO (mm)                       16 non-null     float64
#  1   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  16 non-null     float64
#  2   PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        16 non-null     float64
#  3   PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       16 non-null     float64
#  4   TEMPERATURA DO AR - BULBO SECO. HORARIA (Celsius)      16 non-null     float64
#  5   TEMPERATURA DO PONTO DE ORVALHO (Celsius)              16 non-null     float64
#  6   TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius)        16 non-null     float64
# ...

# %%
# Create feature matrix with two highly correlated features
X = np.array([[1, 1, 1],
              [2, 2, 0],
              [3, 3, 1],
              [4, 4, 0],
              [5, 5, 1],
              [6, 6, 0],
              [7, 7, 1],
              [8, 7, 0],
              [9, 7, 1]])

# Convert feature matrix into DataFrame
df = pd.DataFrame(X)

# View the data frame
df
# Out:
#    0  1  2
# 0  1  1  1
# 1  2  2  0
# 2  3  3  1
# 3  4  4  0
# 4  5  5  1
# 5  6  6  0
# 6  7  7  1
# 7  8  7  0
# 8  9  7  1

# %%
# Create correlation matrix
corr_matrix = df.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find index of feature columns with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]

# %%
df_droped=df.drop(df[to_drop], axis=1)

# %%
to_drop
# Out:
# ['PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)',
#  'PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)',
#  'TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius)',
#  'TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius).1',
#  'TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (Celsius)',
#  'TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (Celsius)',
#  'UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)',
#  'UMIDADE RELATIVA DO AR. HORARIA (%)']

# %%
df_droped
# Out:
#             Data  Hora UTC  PRECIPITACAO TOTAL. HORARIO (mm)  \
# 0     2020/01/01  0000 UTC                               0.0
# 1     2020/01/01  0100 UTC                               0.0
# 2     2020/01/01  0200 UTC                               0.0
# 3     2020/01/01  0300 UTC                               0.0
# 4     2020/01/01  0400 UTC                               0.0
# ...          ...       ...                               ...
# 8776  2020/12/31  1600 UTC                               0.0
# 8777  2020/12/31  1700 UTC                               0.0
# 8778  2020/12/31  1800 UTC                               0.0
# 8779  2020/12/31  1900 UTC                               0.0
# 8780  2020/12/31  2000 UTC                               0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                                 879.3
# 1                                                 880.0
# 2                                                 879.9
# ...
