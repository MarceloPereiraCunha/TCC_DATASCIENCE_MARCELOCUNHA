# %%
#Análise exploratória de Dados em Python
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
path=('/home/marcelo/Documentos/PosGraduacaoDataScience/Disciplinas/Monografia/DadosMonografia/dados_inmet_filtrados_2020.csv')
df=pd.read_csv(path)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8781 entries, 0 to 8780
# Data columns (total 19 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Data                                                   8781 non-null   object
#  1   Hora UTC                                               8781 non-null   object
#  2   PRECIPITACAO TOTAL. HORARIO (mm)                       8781 non-null   float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  8781 non-null   float64
#  4   PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        8781 non-null   float64
#  5   PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       8781 non-null   float64
#  6   RADIACAO GLOBAL (Kj/m3)                                8781 non-null   float64
#  7   TEMPERATURA DO AR - BULBO SECO. HORARIA (Celsius)      8781 non-null   float64
#  8   TEMPERATURA DO PONTO DE ORVALHO (Celsius)              8781 non-null   float64
#  9   TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius)        8781 non-null   float64
#  10  TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius).1      8781 non-null   float64
#  11  TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (Celsius)  8781 non-null   float64
#  12  TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (Celsius)  8781 non-null   float64
#  13  UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)               8781 non-null   float64
#  14  UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)               8781 non-null   float64
#  15  UMIDADE RELATIVA DO AR. HORARIA (%)                    8781 non-null   float64
#  16  VENTO. DIRECAO HORARIA (gr) ((gr))                     8781 non-null   float64
#  17  VENTO. RAJADA MAXIMA (m/s)                             8781 non-null   float64
#  18  VENTO. VELOCIDADE HORARIA (m/s);                       8763 non-null   float64
# dtypes: float64(17), object(2)
# memory usage: 1.3+ MB

# %%
df.head(5)
# Out:
#          Data  Hora UTC  PRECIPITACAO TOTAL. HORARIO (mm)  \
# 0  2020/01/01  0000 UTC                               0.0
# 1  2020/01/01  0100 UTC                               0.0
# 2  2020/01/01  0200 UTC                               0.0
# 3  2020/01/01  0300 UTC                               0.0
# 4  2020/01/01  0400 UTC                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 0                                              879.3
# 1                                              880.0
# 2                                              879.9
# 3                                              879.7
# 4                                              879.4
#
#    PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            879.3
# 1                                            880.0
# 2                                            880.1
# 3                                            880.0
# 4                                            879.7
#
#    PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (Kj/m3)  \
# 0                                             878.4              1293.216226
# 1                                             879.2              1293.216226
# 2                                             879.9              1293.216226
# 3                                             879.6              1293.216226
# 4                                             879.3              1293.216226
#
#    TEMPERATURA DO AR - BULBO SECO. HORARIA (Celsius)  \
# 0                                               20.2
# 1                                               19.8
# 2                                               19.6
# 3                                               19.2
# 4                                               18.7
#
#    TEMPERATURA DO PONTO DE ORVALHO (Celsius)  \
# 0                                       16.1
# 1                                       15.8
# 2                                       15.4
# 3                                       15.1
# 4                                       14.9
#
#    TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius)  \
# 0                                             20.7
# 1                                             20.2
# 2                                             20.0
# 3                                             19.6
# 4                                             19.2
#
#    TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius).1  \
# 0                                               20.1
# 1                                               19.7
# 2                                               19.6
# 3                                               19.1
# 4                                               18.7
#
#    TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (Celsius)  \
# 0                                               16.3
# 1                                               16.1
# 2                                               15.9
# 3                                               15.4
# 4                                               15.1
#
#    TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (Celsius)  \
# 0                                               16.0
# 1                                               15.8
# 2                                               15.4
# 3                                               15.1
# 4                                               14.9
#
#    UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 0                                      77.0
# 1                                      79.0
# 2                                      79.0
# 3                                      78.0
# 4                                      79.0
#
#    UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 0                                      76.0
# 1                                      77.0
# 2                                      76.0
# 3                                      77.0
# 4                                      77.0
#
#    UMIDADE RELATIVA DO AR. HORARIA (%)  VENTO. DIRECAO HORARIA (gr) ((gr))  \
# 0                                 77.0                               119.0
# 1                                 78.0                                92.0
# 2                                 77.0                               100.0
# 3                                 77.0                               107.0
# 4                                 79.0                               101.0
#
#    VENTO. RAJADA MAXIMA (m/s)  VENTO. VELOCIDADE HORARIA (m/s);
# 0                        10.4                               6.5
# 1                         9.7                               4.5
# 2                         8.7                               6.8
# 3                         9.4                               6.3
# 4                         8.2                               4.7

# %%
df.tail(5)
# Out:
#             Data  Hora UTC  PRECIPITACAO TOTAL. HORARIO (mm)  \
# 8776  2020/12/31  1600 UTC                               0.0
# 8777  2020/12/31  1700 UTC                               0.0
# 8778  2020/12/31  1800 UTC                               0.0
# 8779  2020/12/31  1900 UTC                               0.0
# 8780  2020/12/31  2000 UTC                               0.0
#
#       PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# 8776                                              882.1
# 8777                                              881.1
# 8778                                              880.5
# 8779                                              879.9
# 8780                                              879.9
#
#       PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 8776                                            882.7
# 8777                                            882.1
# 8778                                            881.1
# 8779                                            880.5
# 8780                                            880.0
#
#       PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# 8776                                             882.1
# 8777                                             881.1
# 8778                                             880.5
# 8779                                             879.8
# 8780                                             879.8
#
#       RADIACAO GLOBAL (Kj/m3)  \
# 8776                   3281.9
# 8777                   3601.5
# 8778                   2511.9
# 8779                    806.5
# 8780                    769.1
#
#       TEMPERATURA DO AR - BULBO SECO. HORARIA (Celsius)  \
# 8776                                               27.8
# 8777                                               28.8
# 8778                                               28.1
# 8779                                               27.4
# 8780                                               27.9
#
#       TEMPERATURA DO PONTO DE ORVALHO (Celsius)  \
# 8776                                       17.4
# 8777                                       17.4
# 8778                                       16.9
# 8779                                       16.7
# 8780                                       17.1
#
#       TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius)  \
# 8776                                             29.2
# 8777                                             29.1
# 8778                                             29.8
# 8779                                             28.1
# 8780                                             28.3
#
#       TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius).1  \
# 8776                                               26.1
# 8777                                               27.5
# 8778                                               27.5
# 8779                                               26.7
# 8780                                               27.3
#
#       TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (Celsius)  \
# 8776                                               18.5
# 8777                                               18.2
# 8778                                               18.4
# 8779                                               17.8
# 8780                                               17.3
#
#       TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (Celsius)  \
# 8776                                               16.9
# 8777                                               16.5
# 8778                                               16.6
# 8779                                               16.2
# 8780                                               16.1
#
#       UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# 8776                                      58.0
# 8777                                      56.0
# 8778                                      54.0
# 8779                                      56.0
# 8780                                      53.0
#
#       UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# 8776                                      50.0
# 8777                                      48.0
# 8778                                      47.0
# 8779                                      50.0
# 8780                                      50.0
#
#       UMIDADE RELATIVA DO AR. HORARIA (%)  VENTO. DIRECAO HORARIA (gr) ((gr))  \
# 8776                                 53.0                               311.0
# 8777                                 50.0                               293.0
# 8778                                 51.0                               323.0
# 8779                                 52.0                               340.0
# 8780                                 52.0                               319.0
#
#       VENTO. RAJADA MAXIMA (m/s)  VENTO. VELOCIDADE HORARIA (m/s);
# 8776                         7.2                               3.1
# 8777                         8.5                               3.9
# 8778                         7.2                               2.9
# 8779                         5.8                               1.5
# 8780                         4.5                               1.7

# %%
#Verificando os tipos de dados importados
df.dtypes
# Out:
# Data                                                      object
# Hora UTC                                                  object
# PRECIPITACAO TOTAL. HORARIO (mm)                         float64
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)    float64
# PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          float64
# PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         float64
# RADIACAO GLOBAL (Kj/m3)                                  float64
# TEMPERATURA DO AR - BULBO SECO. HORARIA (Celsius)        float64
# TEMPERATURA DO PONTO DE ORVALHO (Celsius)                float64
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius)          float64
# TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius).1        float64
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (Celsius)    float64
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (Celsius)    float64
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 float64
# UMIDADE RELATIVA DO AR. HORARIA (%)                      float64
# VENTO. DIRECAO HORARIA (gr) ((gr))                       float64
# VENTO. RAJADA MAXIMA (m/s)                               float64
# VENTO. VELOCIDADE HORARIA (m/s);                         float64
# dtype: object

# %%
df.describe()
# Out:
#        PRECIPITACAO TOTAL. HORARIO (mm)  \
# count                       8781.000000
# mean                           0.273642
# std                            2.052392
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                           66.200000
#
#        PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)  \
# count                                        8781.000000
# mean                                          882.947980
# std                                             2.885436
# min                                           872.300000
# 25%                                           881.100000
# 50%                                           882.800000
# 75%                                           884.800000
# max                                           892.500000
#
#        PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# count                                      8781.000000
# mean                                        883.178959
# std                                           2.866747
# min                                         872.800000
# 25%                                         881.400000
# 50%                                         883.100000
# 75%                                         885.000000
# max                                         892.500000
#
#        PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  \
# count                                       8781.000000
# mean                                         882.713316
# std                                            2.895329
# min                                          872.200000
# 25%                                          880.900000
# 50%                                          882.600000
# 75%                                          884.600000
# max                                          892.300000
#
#        RADIACAO GLOBAL (Kj/m3)  \
# count              8781.000000
# mean               1293.216226
# std                 795.499653
# min                   0.000000
# 25%                 928.500000
# 50%                1293.216226
# 75%                1335.300000
# max                4183.000000
#
#        TEMPERATURA DO AR - BULBO SECO. HORARIA (Celsius)  \
# count                                        8781.000000
# mean                                           19.655306
# std                                             4.034454
# min                                             8.100000
# 25%                                            17.000000
# 50%                                            19.200000
# 75%                                            22.100000
# max                                            34.900000
#
#        TEMPERATURA DO PONTO DE ORVALHO (Celsius)  \
# count                                8781.000000
# mean                                   14.740062
# std                                     3.272392
# min                                     1.700000
# 25%                                    12.400000
# 50%                                    15.100000
# 75%                                    17.500000
# max                                    22.100000
#
#        TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius)  \
# count                                      8781.000000
# mean                                         20.362631
# std                                           4.332765
# min                                           8.800000
# 25%                                          17.400000
# 50%                                          19.800000
# 75%                                          23.200000
# max                                          35.300000
#
#        TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius).1  \
# count                                        8781.000000
# mean                                           18.996029
# std                                             3.724635
# min                                             7.700000
# 25%                                            16.500000
# 50%                                            18.800000
# 75%                                            21.100000
# max                                            33.400000
#
#        TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (Celsius)  \
# count                                        8781.000000
# mean                                           15.252111
# std                                             3.309822
# min                                             3.100000
# 25%                                            12.800000
# 50%                                            15.600000
# 75%                                            18.000000
# max                                            23.200000
#
#        TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (Celsius)  \
# count                                        8781.000000
# mean                                           14.243428
# std                                             3.283684
# min                                             1.400000
# 25%                                            11.900000
# 50%                                            14.700000
# 75%                                            17.000000
# max                                            20.100000
#
#        UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)  \
# count                               8781.000000
# mean                                  78.520995
# std                                   16.635963
# min                                   22.000000
# 25%                                   67.000000
# 50%                                   82.000000
# 75%                                   93.000000
# max                                   99.000000
#
#        UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)  \
# count                               8781.000000
# mean                                  72.905865
# std                                   18.415922
# min                                   19.000000
# 25%                                   59.000000
# 50%                                   75.000000
# 75%                                   89.000000
# max                                   99.000000
#
#        UMIDADE RELATIVA DO AR. HORARIA (%)  \
# count                          8781.000000
# mean                             75.811844
# std                              17.612537
# min                              20.000000
# 25%                              63.000000
# 50%                              79.000000
# 75%                              91.000000
# max                              99.000000
#
#        VENTO. DIRECAO HORARIA (gr) ((gr))  VENTO. RAJADA MAXIMA (m/s)  \
# count                         8781.000000                 8781.000000
# mean                           140.941573                    8.640808
# std                             85.580479                    3.411325
# min                              1.000000                    0.900000
# 25%                            100.000000                    6.200000
# 50%                            117.000000                    8.200000
# 75%                            136.000000                   10.600000
# max                            360.000000                   28.800000
#
#        VENTO. VELOCIDADE HORARIA (m/s);
# count                       8763.000000
# mean                           5.002956
# std                            2.636981
# min                            0.100000
# 25%                            2.900000
# 50%                            4.600000
# 75%                            6.700000
# max                           16.400000

# %%
#PRECIPITACAO TOTAL. HORARIO (mm)
boxplot = df.boxplot('PRECIPITACAO TOTAL. HORARIO (mm)')
df.hist(column='PRECIPITACAO TOTAL. HORARIO (mm)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa2c16950>]],
#       dtype=object)

# %%
#PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)
boxplot = df.boxplot('PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)')
df.hist(column='PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO. HORARIA (mB)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa2ac3510>]],
#       dtype=object)

# %%
#PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)
boxplot = df.boxplot('PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)')
df.hist(column='PRESSAO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa29be510>]],
#       dtype=object)

# %%
#PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)VENTO. RAJADA MAXIMA (m/s)
boxplot = df.boxplot('PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)')
df.hist(column='PRESSAO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa290e450>]],
#       dtype=object)

# %%
#TEMPERATURA DO AR - BULBO SECO. HORARIA (CelsiVENTO. DIRECAO HORARIA (gr) ((gr))us)
boxplot = df.boxplot('TEMPERATURA DO AR - BULBO SECO. HORARIA (Celsius)')
df.hist(column='TEMPERATURA DO AR - BULBO SECO. HORARIA (Celsius)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa29fa750>]],
#       dtype=object)

# %%
#TEMPERATURA DO PONTO DE ORVALHO (Celsius)
boxplot = df.boxplot('TEMPERATURA DO PONTO DE ORVALHO (Celsius)')
df.hist(column='TEMPERATURA DO PONTO DE ORVALHO (Celsius)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6faac63490>]],
#       dtype=object)

# %%
#TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius)
boxplot = df.boxplot('TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius)')
df.hist(column='TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa2724e50>]],
#       dtype=object)

# %%
#TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius).1
boxplot = df.boxplot('TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius).1')
df.hist(column='TEMPERATURA MAXIMA NA HORA ANT. (AUT) (Celsius).1')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa26932d0>]],
#       dtype=object)

# %%
#TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (Celsius)
boxplot = df.boxplot('TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (Celsius)')
df.hist(column='TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (Celsius)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa2578210>]],
#       dtype=object)

# %%
#TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (Celsius)
boxplot = df.boxplot('TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (Celsius)')
df.hist(column='TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (Celsius)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa2477650>]],
#       dtype=object)

# %%
#UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)
boxplot = df.boxplot('UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)')
df.hist(column='UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa2563a10>]],
#       dtype=object)

# %%
#UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)
boxplot = df.boxplot('UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)')
df.hist(column='UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa2781050>]],
#       dtype=object)

# %%
#UMIDADE RELATIVA DO AR. HORARIA (%)
boxplot = df.boxplot('UMIDADE RELATIVA DO AR. HORARIA (%)')
df.hist(column='UMIDADE RELATIVA DO AR. HORARIA (%)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa2922790>]],
#       dtype=object)

# %%
#VENTO. DIRECAO HORARIA (gr) ((gr))
boxplot = df.boxplot('VENTO. DIRECAO HORARIA (gr) ((gr))')
df.hist(column='VENTO. DIRECAO HORARIA (gr) ((gr))')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa23435d0>]],
#       dtype=object)

# %%
#VENTO. RAJADA MAXIMA (m/s)
boxplot = df.boxplot('VENTO. RAJADA MAXIMA (m/s)')
df.hist(column='VENTO. RAJADA MAXIMA (m/s)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa223b250>]],
#       dtype=object)

# %%
#VENTO. VELOCIDADE HORARIA (m/s)
boxplot = df.boxplot('VENTO. VELOCIDADE HORARIA (m/s);')
df.hist(column='VENTO. VELOCIDADE HORARIA (m/s);')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6fa2122e90>]],
#       dtype=object)
