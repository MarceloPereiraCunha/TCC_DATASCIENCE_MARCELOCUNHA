# %%
#Obtendo dados do ClimaTempo via API
#Tutorial
#https://www.youtube.com/watch?v=Rm1yjmj3yYc

#API
#https://advisor.climatempo.com.br/home/#!/tokens
#Token para acessar API
#5c71d869f5693cab0fb02c39da8d1cc4


#documentacao em: http://apiadvisor.climatempo.com.br/doc/index.html
import requests
import json #pip install json

iTOKEN = "8c2f52e9921a6556790d9ff7a3f0275c"
#ID DE BHiCIDADE
iCIDADE = "6879"

#Codigo do tipo da consulta
iTIPOCONSULTA = 1

# %%
def buscaDados( iTIPOCONSULTA, iCITY, iTOKEN, iCIDADE ):
    iTOKEN = "Informe seu Token"
    iCIDADE = "6879"
    iCITY = "Belo Horizonte"
    iTOKEN = "Informe seu Token"
    iCIDADE = "Informe o ID da cidade vinculada ao seu Token"

    #Codigo do tipo da consulta
    #iTIPOCONSULTA = 1

    #1=Tempo agora na cidade
    if iTIPOCONSULTA == 1:
        iURL = "http://apiadvisor.climatempo.com.br/api/v1/weather/locale/" + iCIDADE + "/current?token=" + iTOKEN
        iRESPONSE = requests.request("GET", iURL)
        iRETORNO_REQ = json.loads(iRESPONSE.text)
        print(iRETORNO_REQ)

        for iCHAVE in iRETORNO_REQ:
            print(iCHAVE + " : " + str(iRETORNO_REQ[iCHAVE]))

        for iCHAVE in iRETORNO_REQ['data']:
            print(iCHAVE + " : " + str(iRETORNO_REQ['data'][iCHAVE]) )

    #2=Status do tempo no país
    if iTIPOCONSULTA == 2:
        iURL = "http://apiadvisor.climatempo.com.br/api/v1/anl/synoptic/locale/BR?token=" + iTOKEN
        iRESPONSE = requests.request("GET", iURL)
        iRETORNO_REQ = json.loads(iRESPONSE.text)
        #print(iRETORNO_REQ)

        for iCHAVE in iRETORNO_REQ:
            print("Country: " + iCHAVE.get('country'))
            print("date: " + iCHAVE.get('date'))
            print("Text: " + iCHAVE.get('text') + "\n")

    #3=Previsao para os proximas 15 dias
    if iTIPOCONSULTA == 3:
        iURL = "http://apiadvisor.climatempo.com.br/api/v1/forecast/locale/" + iCIDADE + "/days/15?token=" + iTOKEN
        iRESPONSE = requests.request("GET", iURL)
        iRETORNO_REQ = json.loads(iRESPONSE.text)
        #print(iRETORNO_REQ)
        print("\ncidade: " + str(iRETORNO_REQ.get('name')) + "-" + str(iRETORNO_REQ.get('state')))
        for iCHAVE in iRETORNO_REQ['data']:
            iDATA = iCHAVE.get('date_br')
            iCHUVA = iCHAVE['rain']['probability']
            iTEXTMORNING = iCHAVE['text_icon']['text']['phrase']['reduced']
            iTEMPERATURAMIN = iCHAVE['temperature']['min']
            iTEMPERATURAMAX = iCHAVE['temperature']['min']
            print("data: " + str(iDATA) + " chuva: " + str(iCHUVA) + "%" + " temp: min(" + str(iTEMPERATURAMIN) + ") max(" + str(iTEMPERATURAMAX) + ") resumo: " + str(iTEXTMORNING) + "\n")

    #4=Previsao para os proximas 3 dias por regiao
    if iTIPOCONSULTA == 4:
        iURL = "http://apiadvisor.climatempo.com.br/api/v1/forecast/region/centro-oeste?token=" + iTOKEN
        iRESPONSE = requests.request("GET", iURL)
        iRETORNO_REQ = json.loads(iRESPONSE.text)
        #print(iRETORNO_REQ)

        for iCHAVE in iRETORNO_REQ['data']:
            iDATA = iCHAVE.get('date_br')
            iTEXT = (iCHAVE.get('text'))
            if iTEXT == None:
                iTEXT = "sem dados para esta data"
            print("data: " + str(iDATA) + " texto: " + str(iTEXT) + "\n")

    #5=Previsao para as proximas 72 horas
    if iTIPOCONSULTA == 5:
        iURL = "http://apiadvisor.climatempo.com.br/api/v1/forecast/locale/" + iCIDADE + "/hours/72?token=" + iTOKEN
        iRESPONSE = requests.request("GET", iURL)
        iRETORNO_REQ = json.loads(iRESPONSE.text)
        #print(iRETORNO_REQ)

        for iCHAVE in iRETORNO_REQ['data']:
            iDATA = iCHAVE.get('date_br')
            iTEMPERATURA = iCHAVE['temperature']['temperature']
            print("data:" + str(iDATA) + " " + str(iTEMPERATURA) + "º" + "\n")

    #6=Pesquisa ID da Cidade
    if iTIPOCONSULTA == 6:
        iCITY = input('Informe aqui o nome da cidade: ')
        iURL = "http://apiadvisor.climatempo.com.br/api/v1/locale/city?name=" + iCITY + "&token=" + iTOKEN
        iRESPONSE = requests.request("GET", iURL)
        iRETORNO_REQ = json.loads(iRESPONSE.text)
        #print(iRETORNO_REQ)

        for iCHAVE in iRETORNO_REQ:
            iID = iCHAVE['id']
            iNAME = iCHAVE['name']
            iSTATE = iCHAVE['state']
            iCOUNTRY = iCHAVE['country']
            print("id:" + str(iID) + " - " + "stlocalesidate:" + str(iSTATE) + " - " + "country:" + str(iCOUNTRY) + " - " + "name:" + str(iNAME) + "\n") 

        iNEWCITY = input('Informe o ID da nova cidade ou 0(zero) para sair: ')
        if iNEWCITY != "0":
            iURL = "http://apiadvisor.climatempo.com.br/api-manager/user-token/"+ iTOKEN + "/locales" 
            payload="localeId[]=" + iNEWCITY
            headers = {
            'Content-Type': 'application/x-www-form-urlencoded'
            }
            iRESPONSE = requests.request("PUT", iURL, headers=headers, data=payload)
            print(iRESPONSE.text)
        else:
            exit()

    #7=Pesquisar o id da cidade vinculado ao seu Token
    if iTIPOCONSULTA == 7:
        iURL = "http://apiadvisor.climatempo.com.br/api-manager/user-token/" + iTOKEN + "/locales" 
        iRESPONSE = requests.request("GET", iURL)
        iRETORNO_REQ = json.loads(iRESPONSE.text)
        print("id: " + str(iRETORNO_REQ['locales']))

    #8=Pesquisar a cidade por ID
    if iTIPOCONSULTA == 8:
        iURL = "http://apiadvisor.climatempo.com.br/api/v1/locale/city/" + iCIDADE + "?token=" + iTOKEN 
        iRESPONSE = requests.request("GET", iURL)
        iRETORNO_REQ = json.loads(iRESPONSE.text)
        #print(iRETORNO_REQ)

        print("id: " + str(iRETORNO_REQ.get('id')))
        print("name: " + str(iRETORNO_REQ.get('name')))
        print("state: " + str(iRETORNO_REQ.get('state')))
        print("country: " + str(iRETORNO_REQ.get('country')) + "\n")

    #9=Alterar o ID da cidade relacionada ao Token
    if iTIPOCONSULTA == 9:
        iURL = "http://apiadvisor.climatempo.com.br/api-manager/user-token/"+ iTOKEN + "/locales" 
        payload="localeId[]=" + iCIDADE
        headers = {
        'Content-Type': 'application/x-www-form-urlencoded'
        }
        iRESPONSE = requests.request("PUT", iURL, headers=headers, data=payload)
        print(iRESPONSE.text)

        #################################################################
        return
    ###############################

# %%
#input: token e nome da cidade
#output: código da cidade

def buscaIDCidade (iTOKEN, iCITY):
    iURL = "http://apiadvisor.climatempo.com.br/api/v1/locale/city?name=" + iCITY + "&token=" + iTOKEN
    iRESPONSE = requests.request("GET", iURL)
    iRETORNO_REQ = json.loads(iRESPONSE.text)

    for iCHAVE in iRETORNO_REQ:
        iID = iCHAVE['id']
        iNAME = iCHAVE['name']
        iSTATE = iCHAVE['state']
        iCOUNTRY = iCHAVE['country']
    return str(iID)

# %%
#Teste buscaIDCidade()
print(buscaIDCidade(iTOKEN, 'Belo Horizonte'))
# Out:
# 6879

# %%
#inout: token, id Cidade
#output: pressao, sensacao termica, temperatura e data

def buscaDadosTempoAtual(iTOKEN, iCIDADE):
    iURL = "http://apiadvisor.climatempo.com.br/api/v1/weather/locale/" + iCIDADE + "/current?token=" + iTOKEN
    iRESPONSE = requests.request("GET", iURL)
    iRETORNO_REQ = json.loads(iRESPONSE.text)
    #print(iRETORNO_REQ)

    #for iCHAVE in iRETORNO_REQ:
        #print(iCHAVE + " : " + str(iRETORNO_REQ[iCHAVE]))

    #for iCHAVE in iRETORNO_REQ['data']:
        #print(iCHAVE + " : " + str(iRETORNO_REQ['data'][iCHAVE]) )
    dadosAtuais ={
        'Pressao': iRETORNO_REQ['data']['pressure'],
        'Sensacao': iRETORNO_REQ['data']['sensation'],
        'Temperatura': iRETORNO_REQ['data']['temperature'],
        'Data': iRETORNO_REQ['data']['date']
    }
    return dadosAtuais

# %%
#TESTE buscaDadosTempoAtual():
print(buscaDadosTempoAtual(iTOKEN, '6879'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-0ff18cc6099a> in <module>
#       1 #TESTE buscaDadosTempoAtual():
# ----> 2 print(buscaDadosTempoAtual(iTOKEN, '6879'))
#
# <ipython-input-6-142fbf793dde> in buscaDadosTempoAtual(iTOKEN, iCIDADE)
#       4 def buscaDadosTempoAtual(iTOKEN, iCIDADE):
#       5     iURL = "http://apiadvisor.climatempo.com.br/api/v1/weather/locale/" + iCIDADE + "/current?token=" + iTOKEN
# ----> 6     iRESPONSE = requests.request("GET", iURL)
#       7     iRETORNO_REQ = json.loads(iRESPONSE.text)
#       8     #print(iRETORNO_REQ)
#
# NameError: name 'requests' is not defined

# %%
#input: token
#output: dictionary contendo dados da previsão

def buscaDadosTempoPais(iTOKEN):
    iURL = "http://apiadvisor.climatempo.com.br/api/v1/anl/synoptic/locale/BR?token=" + iTOKEN
    iRESPONSE = requests.request("GET", iURL)
    iRETORNO_REQ = json.loads(iRESPONSE.text)
    #print(iRETORNO_REQ)

    for iCHAVE in iRETORNO_REQ:
        print("Country: " + iCHAVE.get('country'))
        print("date: " + iCHAVE.get('date'))
        print("Text: " + iCHAVE.get('text') + "\n")
    #dadosPais = {
     #   'Pais': iRETORNO_REQ['data']['country'],
      #  'Data': iRETORNO_REQ['data']['date'],
       # 'Texto': iRETORNO_REQ['data']['text'],
    #}
    return iCHAVE
    #return dadosPais

# %%
#Teste buscaDadosTempoPais()
iTOKEN = '8c2f52e9921a6556790d9ff7a3f0275c'
print(buscaDadosTempoPais(iTOKEN))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5c86557c4e5f> in <module>
#       1 #Teste buscaDadosTempoPais()
#       2 iTOKEN = '8c2f52e9921a6556790d9ff7a3f0275c'
# ----> 3 print(buscaDadosTempoPais(iTOKEN))
#
# <ipython-input-2-a91b8e8f4a30> in buscaDadosTempoPais(iTOKEN)
#       4 def buscaDadosTempoPais(iTOKEN):
#       5     iURL = "http://apiadvisor.climatempo.com.br/api/v1/anl/synoptic/locale/BR?token=" + iTOKEN
# ----> 6     iRESPONSE = requests.request("GET", iURL)
#       7     iRETORNO_REQ = json.loads(iRESPONSE.text)
#       8     #print(iRETORNO_REQ)
#
# NameError: name 'requests' is not defined

# %%
#Inputs: iCIDADE, iTOKEN 
#Output: Dicionário contendo dados de previsão para os proximos 15 dias
def buscaPrevisao15Dias(iCIDADE, iTOKEN ):
    iURL = "http://apiadvisor.climatempo.com.br/api/v1/forecast/locale/" + iCIDADE + "/days/15?token=" + iTOKEN
    iRESPONSE = requests.request("GET", iURL)
    iRETORNO_REQ = json.loads(iRESPONSE.text)
    #print(iRETORNO_REQ)
    print("\ncidade: " + str(iRETORNO_REQ.get('name')) + "-" + str(iRETORNO_REQ.get('state')))
    
    for iCHAVE in iRETORNO_REQ['data']:
        iDATA = iCHAVE.get('date_br')
        iCHUVA = iCHAVE['rain']['probability']
        iTEXTMORNING = iCHAVE['text_icon']['text']['phrase']['reduced']
        iTEMPERATURAMIN = iCHAVE['temperature']['min']
        iTEMPERATURAMAX = iCHAVE['temperature']['min']
        print("data: " + str(iDATA) + " chuva: " + str(iCHUVA) + "%" + " temp: min(" + str(iTEMPERATURAMIN) + ") max(" + str(iTEMPERATURAMAX) + ") resumo: " + str(iTEXTMORNING) + "\n")

6879

# %%
#Teste buscaPrevisao15Dias(iCIDADE, iTOKEN )
buscaPrevisao15Dias(iCIDADE, iTOKEN)

# %%
 def buscaPrevisao3Dias(iTOKEN):
    iURL = "http://apiadvisor.climatempo.com.br/api/v1/forecast/region/centro-oeste?token=" + iTOKEN
    iRESPONSE = requests.request("GET", iURL)
    iRETORNO_REQ = json.loads(iRESPONSE.text)
    cont = 0
    dadosPrevistos ={}
    
    for iCHAVE in iRETORNO_REQ['data']:
        iDATA = iCHAVE.get('date_br')
        iTEXT = (iCHAVE.get('text'))
        if iTEXT == None:
            iTEXT = "sem dados para esta data"
        #print("data: " + str(iDATA) + " texto: " + str(iTEXT) + "\n")
        dadosPrevistos[cont] = 'Data: ' + str(iDATA) + ' ' + 'Texto: ' + str(iTEXT)
        cont=cont+1
        
    return dadosPrevistos

# %%
#TESTE buscaPrevisao3Dias(iTOKEN)
print(buscaPrevisao3Dias(iTOKEN))
# Out:
# {0: 'Data: 03/07/2021 Texto: sem dados para esta data', 1: 'Data: 04/07/2021 Texto: No domingo, o sol aparece forte ao longo do dia e não chove. Apesar de a última semana ter sido fria, as temperaturas começam entrar em elevação na Região.', 2: 'Data: 05/07/2021 Texto: Um sistema de alta pressão atmosférica vai continuar impedindo nuvens carregadas e a segunda-feira vai ser marcada por sol, calor e tempo firme por toda a Região Centro-Oeste. '}

# %%
#inputs: cod cidade e token
#outputs: dicionario contendo previsao para as proximas 72 horas na cidade em questao
def buscaPrevisao72HorasRegiao(iCIDADE, iTOKEN):
    iURL = "http://apiadvisor.climatempo.com.br/api/v1/forecast/locale/" + iCIDADE + "/hours/72?token=" + iTOKEN
    iRESPONSE = requests.request("GET", iURL)
    iRETORNO_REQ = json.loads(iRESPONSE.text)
    #print(iRETORNO_REQ)
    
    cont = 0
    dadosPrevistos ={}6879

    for iCHAVE in iRETORNO_REQ['data']:
        iDATA = iCHAVE.get('date_br')
        iTEMPERATURA = iCHAVE['temperature']['temperature']
        #rint("data:" + str(iDATA) + " " + str(iTEMPERATURA) + "º" + "\n")
        dadosPrevistos[cont] = 'Data: ' + str(iDATA) + ' ' + 'Temperatura ºC: ' + str(iTEMPERATURA)
        cont = cont+1
    return dadosPrevistos

# %%
#TESTE buscaPrevisao72HorasRegiao(iCIDADE, iTOKEN)
buscaPrevisao72HorasRegiao('6879', "8c2f52e9921a6556790d9ff7a3f0275c")
# Out:
# {0: 'Data: 03/07/2021 00:00:00 Temperatura ºC: 15',
#  1: 'Data: 03/07/2021 01:00:00 Temperatura ºC: 15',
#  2: 'Data: 03/07/2021 02:00:00 Temperatura ºC: 14',
#  3: 'Data: 03/07/2021 03:00:00 Temperatura ºC: 13',
#  4: 'Data: 03/07/2021 04:00:00 Temperatura ºC: 12',
#  5: 'Data: 03/07/2021 05:00:00 Temperatura ºC: 11',
#  6: 'Data: 03/07/2021 06:00:00 Temperatura ºC: 11',
#  7: 'Data: 03/07/2021 07:00:00 Temperatura ºC: 10',
#  8: 'Data: 03/07/2021 08:00:00 Temperatura ºC: 10',
#  9: 'Data: 03/07/2021 09:00:00 Temperatura ºC: 10',
#  10: 'Data: 03/07/2021 10:00:00 Temperatura ºC: 10',
#  11: 'Data: 03/07/2021 11:00:00 Temperatura ºC: 14',
#  12: 'Data: 03/07/2021 12:00:00 Temperatura ºC: 17',
#  13: 'Data: 03/07/2021 13:00:00 Temperatura ºC: 18',
#  14: 'Data: 03/07/2021 14:00:00 Temperatura ºC: 20',
#  15: 'Data: 03/07/2021 15:00:00 Temperatura ºC: 22',
#  16: 'Data: 03/07/2021 16:00:00 Temperatura ºC: 24',
#  17: 'Data: 03/07/2021 17:00:00 Temperatura ºC: 25',
#  18: 'Data: 03/07/2021 18:00:00 Temperatura ºC: 23',
#  19: 'Data: 03/07/2021 19:00:00 Temperatura ºC: 24',
#  20: 'Data: 03/07/2021 20:00:00 Temperatura ºC: 22',
#  21: 'Data: 03/07/2021 21:00:00 Temperatura ºC: 20',
#  22: 'Data: 03/07/2021 22:00:00 Temperatura ºC: 17',
#  23: 'Data: 03/07/2021 23:00:00 Temperatura ºC: 16',
#  24: 'Data: 04/07/2021 00:00:00 Temperatura ºC: 15',
#  25: 'Data: 04/07/2021 01:00:00 Temperatura ºC: 14',
#  26: 'Data: 04/07/2021 02:00:00 Temperatura ºC: 14',
#  27: 'Data: 04/07/2021 03:00:00 Temperatura ºC: 13',
#  28: 'Data: 04/07/2021 04:00:00 Temperatura ºC: 13',
#  29: 'Data: 04/07/2021 05:00:00 Temperatura ºC: 14',
#  30: 'Data: 04/07/2021 06:00:00 Temperatura ºC: 13',
#  31: 'Data: 04/07/2021 07:00:00 Temperatura ºC: 12',
#  32: 'Data: 04/07/2021 08:00:00 Temperatura ºC: 11',
#  33: 'Data: 04/07/2021 09:00:00 Temperatura ºC: 11',
#  34: 'Data: 04/07/2021 10:00:00 Temperatura ºC: 11',
#  35: 'Data: 04/07/2021 11:00:00 Temperatura ºC: 15',
#  36: 'Data: 04/07/2021 12:00:00 Temperatura ºC: 18',
#  37: 'Data: 04/07/2021 13:00:00 Temperatura ºC: 20',
#  38: 'Data: 04/07/2021 14:00:00 Temperatura ºC: 23',
#  39: 'Data: 04/07/2021 15:00:00 Temperatura ºC: 25',
#  40: 'Data: 04/07/2021 16:00:00 Temperatura ºC: 24',
#  41: 'Data: 04/07/2021 17:00:00 Temperatura ºC: 25',
#  42: 'Data: 04/07/2021 18:00:00 Temperatura ºC: 25',
#  43: 'Data: 04/07/2021 19:00:00 Temperatura ºC: 23',
#  44: 'Data: 04/07/2021 20:00:00 Temperatura ºC: 22',
#  45: 'Data: 04/07/2021 21:00:00 Temperatura ºC: 22',
#  46: 'Data: 04/07/2021 22:00:00 Temperatura ºC: 20',
#  47: 'Data: 04/07/2021 23:00:00 Temperatura ºC: 18',
#  48: 'Data: 05/07/2021 00:00:00 Temperatura ºC: 16',
#  49: 'Data: 05/07/2021 01:00:00 Temperatura ºC: 15',
#  50: 'Data: 05/07/2021 02:00:00 Temperatura ºC: 14',
#  51: 'Data: 05/07/2021 03:00:00 Temperatura ºC: 13',
#  52: 'Data: 05/07/2021 04:00:00 Temperatura ºC: 13',
#  53: 'Data: 05/07/2021 05:00:00 Temperatura ºC: 12',
#  54: 'Data: 05/07/2021 06:00:00 Temperatura ºC: 11',
#  55: 'Data: 05/07/2021 07:00:00 Temperatura ºC: 11',
#  56: 'Data: 05/07/2021 08:00:00 Temperatura ºC: 10',
#  57: 'Data: 05/07/2021 09:00:00 Temperatura ºC: 10',
#  58: 'Data: 05/07/2021 10:00:00 Temperatura ºC: 11',
#  59: 'Data: 05/07/2021 11:00:00 Temperatura ºC: 14',
#  60: 'Data: 05/07/2021 12:00:00 Temperatura ºC: 18',
#  61: 'Data: 05/07/2021 13:00:00 Temperatura ºC: 20',
#  62: 'Data: 05/07/2021 14:00:00 Temperatura ºC: 22',
#  63: 'Data: 05/07/2021 15:00:00 Temperatura ºC: 24',
#  64: 'Data: 05/07/2021 16:00:00 Temperatura ºC: 25',
#  65: 'Data: 05/07/2021 17:00:00 Temperatura ºC: 25',
#  66: 'Data: 05/07/2021 18:00:00 Temperatura ºC: 24',
#  67: 'Data: 05/07/2021 19:00:00 Temperatura ºC: 23',
#  68: 'Data: 05/07/2021 20:00:00 Temperatura ºC: 21',
#  69: 'Data: 05/07/2021 21:00:00 Temperatura ºC: 19',
#  70: 'Data: 05/07/2021 22:00:00 Temperatura ºC: 18',
#  71: 'Data: 05/07/2021 23:00:00 Temperatura ºC: 16'}

# %%
#inputs: código da cidade e token
#output: dicionario contendo dados da cidade
def buscarCidadePeloID(iCIDADE, iTOKEN):
    iURL = "http://apiadvisor.climatempo.com.br/api/v1/locale/city/" + iCIDADE + "?token=" + iTOKEN 
    iRESPONSE = requests.request("GET", iURL)
    iRETORNO_REQ = json.loads(iRESPONSE.text)
    #print(iRETORNO_REQ)

    #print("id: " + str(iRETORNO_REQ.get('id')))
    #print("name: " + str(iRETORNO_REQ.get('name')))
    #print("state: " + str(iRETORNO_REQ.get('state')))
    #print("country: " + str(iRETORNO_REQ.get('country')) + "\n")
    
    dadosCidade ={
        'id': str(iRETORNO_REQ.get('id')),
        'Nome': str(iRETORNO_REQ.get('name')),
        'Estado': str(iRETORNO_REQ.get('state')),
        'País': str(iRETORNO_REQ.get('country'))
    }
    return dadosCidade

# %%
print(buscarCidadePeloID('6879', "8c2f52e9921a6556790d9ff7a3f0275c"))
# Out:
# {'id': '6879', 'Nome': 'Belo Horizonte', 'Estado': 'MG', 'País': 'BR  '}
